# %%
rm(list=ls())
library(readr)
df <- read_table("http://azzalini.stat.unipd.it/Book-DM/yesterday.dat")[-31,]
# Out:
# ── Column specification ────────────────────────────────────────────────────────
# cols(
#   x = col_double(),
#   y.yesterday = col_double(),
#   y.tomorrow = col_double()
# )

# %%
df
# Out:
#    x         y.yesterday y.tomorrow
# 1  0.5000000 0.4269584   0.4468527
# 2  0.5862069 0.4841696   0.4769383
# 3  0.6724138 0.4957393   0.5109149
# 4  0.7586207 0.5438164   0.5130406
# 5  0.8448276 0.5379404   0.5231111
# 6  0.9310345 0.5375140   0.5526467
# 7  1.0172414 0.5401231   0.5371602
# 8  1.1034483 0.5447002   0.5485324
# 9  1.1896552 0.5453667   0.5446904
# 10 1.2758621 0.5337212   0.5325971
# 11 1.3620690 0.5360551   0.5432252
# 12 1.4482759 0.5482129   0.5316430
# 13 1.5344828 0.5277309   0.5189950
# 14 1.6206897 0.5032543   0.5243238
# 15 1.7068966 0.5094058   0.5277170
# 16 1.7931034 0.5049205   0.5028689
# 17 1.8793103 0.5224972   0.5274091
# 18 1.9655172 0.5278002   0.5019069
# 19 2.0517241 0.5249105   0.5037381
# 20 2.1379310 0.5106958   0.5030663
# 21 2.2241379 0.5027985   0.4993774
# 22 2.3103448 0.4895309   0.5153410
# 23 2.3965517 0.5117247   0.5086377
# 24 2.4827586 0.5131897   0.5068553
# 25 2.5689655 0.4986823   0.4912001
# 26 2.6551724 0.5110766   0.5021926
# ...
